# %%
    nbconvert_handlers: "https://github.com/jupyter/notebook/blob/588b1f8eb3e3ee6f5a653d8f22faf8d7d22ae775/notebook/nbconvert/handlers.py"
    nbconvert_handlers_test:'https://github.com/jupyter/notebook/blob/b8b66332e2023e83d2ee04f83d8814f567e01a4e/notebook/nbconvert/tests/test_nbconvert_handlers.py#L27'
    jupyter_server_api: "https://github.com/jupyter/jupyter/wiki/Jupyter-Notebook-Server-API"
    large_file_manager: "https://github.com/jupyter/notebook/blob/master/notebook/services/contents/largefilemanager.py"

    __annotations__
