# %%
    import annodize, typing
    annodize
# Out:
# <module 'annodize' from '/Users/tonyfast/annodize/annodize.py'>

# %%
    import pandas
    np = pandas.np
    xx: annodize.Priority(tuple('pandas.Series numpy.array np.array list'.split()), _coerce=True) = [10]
    annodize.annodize(__name__)
    q = xx
    annodize.annodize(__name__)
    assert q is xx
    xx
# Out:
# 0    10
# dtype: int64

# %%
    del pandas
    annodize.annodize(__name__)
    xx
# Out:
# array([10])

# %%
    del np
    annodize.annodize(__name__)
    xx
# Out:
# [10]

# %%
    import numpy
    annodize.annodize(__name__)
    xx
# Out:
# array([10])

# %%
    import pandas;
    annodize.annodize(__name__) or xx
# Out:
# 0    10
# dtype: int64

# %%
    del pandas, numpy
    annodize.annodize(__name__)
    xx
# Out:
# [10]

# %%
    # %load_ext annodize

# %%
    xx
# Out:
# [10]

# %%
    import pandas, numpy

# %%
    q = xx
    xx
# Out:
# 0    10
# dtype: int64

# %%
    assert q is xx

# %%
    del pandas

# %%
    xx
# Out:
# array([10])

# %%
    del numpy

# %%
    xx
# Out:
# [10]

# %%
    # %unload_ext annodize

# %%
    import pandas

# %%
    xx
# Out:
# [10]

# %%
    annodize.annodize(__name__)
    xx
# Out:
# 0    10
# dtype: int64

# %%
    # %load_ext annodize

# %%
    import panel

# %%
    foo: annodize.Forward('panel.widgets.IntSlider', _observe='value', _coerce=True)  =2
# Out:
# IntSlider(value=2)

# %%
    foo: annodize.Forward('ipywidgets.IntSlider', _observe='value', _coerce=True)

# %%
    import ipywidgets
# Out:
# IntSlider(value=2, description='foo')

# %%
    import ipywidgets

# %%
    del ipywidgets

# %%
    foo: annodize.Forward('ipywidgets.IntSlider', _observe='value', _coerce=True)

# %%
    import ipywidgets
    foo: annodize.Forward('ipywidgets.IntSlider', _observe='value', _coerce=True)
# Out:
# IntSlider(value=2, description='foo')

# %%
    foo
# Out:
# 2

# %%
    assert foo is __annotations__['foo'].__forward_display__.value
    __annotations__['foo'].__forward_display__.value = 10

# %%
    assert foo is 10

# %%
    # %unload_ext annodize

# %%
    with __import__('importnb').Notebook():
        import test_types

# %%
    import ipywidgets
    bar: int = 9
    baz: str = 'help me'
    annodize.annodize(__name__, test_types.__annotations__)
# Out:
# IntText(value=9, description='bar')
# Text(value='help me', description='baz')

# %%
    jawn: typing.List[int] = range(3)
    annodize.annodize(__name__, test_types.__annotations__)
    jawn
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
    jawn: typing.List[float] = range(3)
    annodize.annodize(__name__, test_types.__annotations__)
    jawn
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64

# %%
    del pandas
    jawn: typing.List[float] = range(3)
    annodize.annodize(__name__, test_types.__annotations__)
    jawn
# Out:
# range(0, 3)

# %%
    with __import__('importnb').Notebook(): import test_types
    test_types.__annotations__
# Out:
# {'int': Forward('ipywidgets.IntText'),
#  'float': Forward('ipywidgets.FloatText'),
#  'str': Forward('ipywidgets.Text'),
#  'list': Priority(('pandas.Series', 'numpy.array', 'np.array', 'list')),
#  typing.List[int]: Forward('pandas.Series'),
#  typing.List[float]: Forward('pandas.Series'),
#  typing.List[list]: Priority((Forward('pandas.DataFrame'), Forward('numpy.array'), Forward('np.array')))}

# %%
    jawn: typing.List[list] = [list(range(3))]*3
    annodize.annodize(__name__, test_types.__annotations__)
    jawn
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %%
    import pandas
    annodize.annodize(__name__, test_types.__annotations__)
    jawn
# Out:
#      0    1    2
# 0  0.0  1.0  2.0
# 1  0.0  1.0  2.0
# 2  0.0  1.0  2.0
